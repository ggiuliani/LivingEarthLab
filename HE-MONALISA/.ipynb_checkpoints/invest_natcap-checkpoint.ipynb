# %% [markdown]
# # NatCap InVEST models
# https://naturalcapitalproject.stanford.edu/software/invest

# %% [markdown]
# ## Carbon storage and sequestration
# https://naturalcapitalproject.stanford.edu/invest/carbon

# %%
#Carbon storage
import logging
import sys

import natcap.invest.carbon
import natcap.invest.utils

LOGGER = logging.getLogger(__name__)
root_logger = logging.getLogger()

handler = logging.StreamHandler(sys.stdout)
formatter = logging.Formatter(
    fmt=natcap.invest.utils.LOG_FMT,
    datefmt='%m/%d/%Y %H:%M:%S ')
handler.setFormatter(formatter)
logging.basicConfig(level=logging.INFO, handlers=[handler])

args = {
    'calc_sequestration': False,
    'carbon_pools_path': '/Users/gregorygiuliani/Desktop/invest/carbon_pools.csv', #mandatory
    'discount_rate': '',
    'do_valuation': False,
    'lulc_alt_path': '',
    'lulc_alt_year': '',
    'lulc_bas_path': '/Users/gregorygiuliani/Desktop/invest/level3_out_ch_2018.tif', #mandatory
    'lulc_bas_year': '2018',
    'price_per_metric_ton_of_c': '',
    'rate_change': '',
    'results_suffix': '',
    'workspace_dir': '/Users/gregorygiuliani/Desktop/invest', #mandatory
}

if __name__ == '__main__':
    natcap.invest.carbon.execute(args)
# Out:
# 11/06/2025 14:17:42  (natcap.invest.carbon) carbon.execute(416) INFO Map all carbon pools to carbon storage rasters.
# 11/06/2025 14:17:42  (natcap.invest.carbon) carbon.execute(430) INFO Mapping carbon from 'lulc_bas_path' to 'c_above_bas' scenario.
# 11/06/2025 14:17:42  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(428) INFO starting stats_worker
# 11/06/2025 14:17:42  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(434) INFO started stats_worker <Thread(Thread-4 (stats_worker), started daemon 13053751296)>
# 11/06/2025 14:17:47  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_above_bas.tif 19.8% complete
# 11/06/2025 14:17:52  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_above_bas.tif 38.8% complete
# 11/06/2025 14:17:57  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_above_bas.tif 57.1% complete
# 11/06/2025 14:18:02  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_above_bas.tif 75.2% complete
# 11/06/2025 14:18:07  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_above_bas.tif 94.1% complete
# 11/06/2025 14:18:09  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(516) INFO 100.0% complete
# 11/06/2025 14:18:09  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(519) INFO Waiting for raster stats worker result.
# 11/06/2025 14:18:09  (natcap.invest.carbon) carbon.execute(430) INFO Mapping carbon from 'lulc_bas_path' to 'c_below_bas' scenario.
# 11/06/2025 14:18:09  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(428) INFO starting stats_worker
# 11/06/2025 14:18:09  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(434) INFO started stats_worker <Thread(Thread-5 (stats_worker), started daemon 13053751296)>
# 11/06/2025 14:18:14  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_below_bas.tif 18.1% complete
# 11/06/2025 14:18:19  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_below_bas.tif 35.8% complete
# 11/06/2025 14:18:24  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_below_bas.tif 53.6% complete
# 11/06/2025 14:18:29  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_below_bas.tif 70.9% complete
# 11/06/2025 14:18:34  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_below_bas.tif 87.4% complete
# 11/06/2025 14:18:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(516) INFO 100.0% complete
# 11/06/2025 14:18:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(519) INFO Waiting for raster stats worker result.
# 11/06/2025 14:18:38  (natcap.invest.carbon) carbon.execute(430) INFO Mapping carbon from 'lulc_bas_path' to 'c_soil_bas' scenario.
# 11/06/2025 14:18:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(428) INFO starting stats_worker
# 11/06/2025 14:18:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(434) INFO started stats_worker <Thread(Thread-6 (stats_worker), started daemon 13053751296)>
# 11/06/2025 14:18:43  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_soil_bas.tif 16.3% complete
# 11/06/2025 14:18:48  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_soil_bas.tif 32.6% complete
# 11/06/2025 14:18:53  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_soil_bas.tif 49.5% complete
# 11/06/2025 14:18:58  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_soil_bas.tif 65.7% complete
# 11/06/2025 14:19:03  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_soil_bas.tif 82.7% complete
# 11/06/2025 14:19:08  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_soil_bas.tif 99.8% complete
# 11/06/2025 14:19:08  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(516) INFO 100.0% complete
# 11/06/2025 14:19:08  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(519) INFO Waiting for raster stats worker result.
# 11/06/2025 14:19:08  (natcap.invest.carbon) carbon.execute(430) INFO Mapping carbon from 'lulc_bas_path' to 'c_dead_bas' scenario.
# 11/06/2025 14:19:08  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(428) INFO starting stats_worker
# 11/06/2025 14:19:08  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(434) INFO started stats_worker <Thread(Thread-7 (stats_worker), started daemon 13053751296)>
# 11/06/2025 14:19:13  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_dead_bas.tif 14.6% complete
# 11/06/2025 14:19:18  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_dead_bas.tif 30.0% complete
# 11/06/2025 14:19:23  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_dead_bas.tif 47.3% complete
# 11/06/2025 14:19:28  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_dead_bas.tif 63.7% complete
# 11/06/2025 14:19:33  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_dead_bas.tif 78.0% complete
# 11/06/2025 14:19:38  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_dead_bas.tif 95.5% complete
# 11/06/2025 14:19:39  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(516) INFO 100.0% complete
# 11/06/2025 14:19:39  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(519) INFO Waiting for raster stats worker result.
# 11/06/2025 14:19:39  (natcap.invest.carbon) carbon.execute(443) INFO Calculate carbon storage for 'c_storage_bas'
# 11/06/2025 14:19:39  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(428) INFO starting stats_worker
# 11/06/2025 14:19:39  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(434) INFO started stats_worker <Thread(Thread-8 (stats_worker), started daemon 13053751296)>
# 11/06/2025 14:19:44  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_storage_bas.tif 14.2% complete
# 11/06/2025 14:19:49  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_storage_bas.tif 29.8% complete
# 11/06/2025 14:19:54  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_storage_bas.tif 42.8% complete
# 11/06/2025 14:19:59  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_storage_bas.tif 58.1% complete
# 11/06/2025 14:20:04  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_storage_bas.tif 73.2% complete
# 11/06/2025 14:20:09  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(511) INFO c_storage_bas.tif 87.6% complete
# 11/06/2025 14:20:13  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(516) INFO 100.0% complete
# 11/06/2025 14:20:13  (pygeoprocessing.geoprocessing) geoprocessing.raster_calculator(519) INFO Waiting for raster stats worker result.

# %% [markdown]
# ## Crop pollination
# https://naturalcapitalproject.stanford.edu/invest/crop-pollination

# %%
import logging
import sys

import natcap.invest.pollination
import natcap.invest.utils

LOGGER = logging.getLogger(__name__)
root_logger = logging.getLogger()

handler = logging.StreamHandler(sys.stdout)
formatter = logging.Formatter(
    fmt=natcap.invest.utils.LOG_FMT,
    datefmt='%m/%d/%Y %H:%M:%S ')
handler.setFormatter(formatter)
logging.basicConfig(level=logging.INFO, handlers=[handler])

args = {
    'farm_vector_path': '',
    'guild_table_path': '', #mandatory
    'landcover_biophysical_table_path': '', #mandatory
    'landcover_raster_path': '', #mandatory
    'results_suffix': '',
    'workspace_dir': '', #mandatory
}

if __name__ == '__main__':
    natcap.invest.pollination.execute(args)

# %% [markdown]
# ## Crop production
# https://naturalcapitalproject.stanford.edu/invest/crop-production

# %% [markdown]
# ## Forest carbon edge effect
# https://naturalcapitalproject.stanford.edu/carbon-edge-effect

# %%
import logging
import sys

import natcap.invest.forest_carbon_edge_effect
import natcap.invest.utils

LOGGER = logging.getLogger(__name__)
root_logger = logging.getLogger()

handler = logging.StreamHandler(sys.stdout)
formatter = logging.Formatter(
    fmt=natcap.invest.utils.LOG_FMT,
    datefmt='%m/%d/%Y %H:%M:%S ')
handler.setFormatter(formatter)
logging.basicConfig(level=logging.INFO, handlers=[handler])

args = {
    'aoi_vector_path': '',
    'biomass_to_carbon_conversion_factor': '',
    'biophysical_table_path': '', #mandatory
    'compute_forest_edge_effects': False,
    'lulc_raster_path': '', #mandatory
    'n_nearest_model_points': '',
    'pools_to_calculate': 'all',
    'results_suffix': '',
    'tropical_forest_edge_carbon_model_vector_path': '',
    'workspace_dir': '', #mandatory
}

if __name__ == '__main__':
    natcap.invest.forest_carbon_edge_effect.execute(args)

# %% [markdown]
# ## Habitat quality
# https://naturalcapitalproject.stanford.edu/invest/habitat-quality

# %%
import logging
import sys

import natcap.invest.habitat_quality
import natcap.invest.utils

LOGGER = logging.getLogger(__name__)
root_logger = logging.getLogger()

handler = logging.StreamHandler(sys.stdout)
formatter = logging.Formatter(
    fmt=natcap.invest.utils.LOG_FMT,
    datefmt='%m/%d/%Y %H:%M:%S ')
handler.setFormatter(formatter)
logging.basicConfig(level=logging.INFO, handlers=[handler])

args = {
    'access_vector_path': '',
    'half_saturation_constant': '', #mandatory
    'lulc_bas_path': '',
    'lulc_cur_path': '', #mandatory
    'lulc_fut_path': '',
    'results_suffix': '',
    'sensitivity_table_path': '', #mandatory
    'threats_table_path': '', #mandatory
    'workspace_dir': '', #mandatory
}

if __name__ == '__main__':
    natcap.invest.habitat_quality.execute(args)

# %% [markdown]
# ## Nutrient delivery ratio
# https://naturalcapitalproject.stanford.edu/invest/water-purification

# %%
import logging
import sys

import natcap.invest.ndr.ndr
import natcap.invest.utils

LOGGER = logging.getLogger(__name__)
root_logger = logging.getLogger()

handler = logging.StreamHandler(sys.stdout)
formatter = logging.Formatter(
    fmt=natcap.invest.utils.LOG_FMT,
    datefmt='%m/%d/%Y %H:%M:%S ')
handler.setFormatter(formatter)
logging.basicConfig(level=logging.INFO, handlers=[handler])

args = {
    'biophysical_table_path': '', #mandatory
    'calc_n': False,
    'calc_p': False,
    'dem_path': '', #mandatory
    'flow_dir_algorithm': 'D8',
    'k_param': '',
    'lulc_path': '', #mandatory
    'results_suffix': '',
    'runoff_proxy_av': '',
    'runoff_proxy_path': '', #mandatory
    'subsurface_critical_length_n': '',
    'subsurface_eff_n': '',
    'threshold_flow_accumulation': '',
    'watersheds_path': '', #mandatory
    'workspace_dir': '', #mandatory
}

if __name__ == '__main__':
    natcap.invest.ndr.ndr.execute(args)

# %% [markdown]
# ## Sediment delivery ratio
# https://naturalcapitalproject.stanford.edu/invest/sediment-retention

# %%
import logging
import sys

import natcap.invest.sdr.sdr
import natcap.invest.utils

LOGGER = logging.getLogger(__name__)
root_logger = logging.getLogger()

handler = logging.StreamHandler(sys.stdout)
formatter = logging.Formatter(
    fmt=natcap.invest.utils.LOG_FMT,
    datefmt='%m/%d/%Y %H:%M:%S ')
handler.setFormatter(formatter)
logging.basicConfig(level=logging.INFO, handlers=[handler])

args = {
    'biophysical_table_path': '', #mandatory
    'dem_path': '', #mandatory
    'drainage_path': '',
    'erodibility_path': '', #mandatory
    'erosivity_path': '', #mandatory
    'flow_dir_algorithm': 'D8',
    'ic_0_param': '',
    'k_param': '',
    'l_max': '',
    'lulc_path': '', #mandatory
    'results_suffix': '',
    'sdr_max': '',
    'threshold_flow_accumulation': '',
    'watersheds_path': '', #mandatory
    'workspace_dir': '', #mandatory
}

if __name__ == '__main__':
    natcap.invest.sdr.sdr.execute(args)

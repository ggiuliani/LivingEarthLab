# %% [markdown]
# # Vegetation Health Index (VHI)
# ---
# XXX

# %%
import ee
import geemap
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/ipywidgets/widgets/widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/ipywidgets/widgets/widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/contextlib.py:148, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     146 if typ is None:
#     147     try:
# --> 148         next(self.gen)
#     149     except StopIteration:
#     150         return False
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/traitlets/traitlets.py:1510, in HasTraits.hold_trait_notifications(self)
#    1508 for changes in cache.values():
#    1509     for change in changes:
# -> 1510         self.notify_change(change)
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/traitlets/traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/traitlets/traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/geemap/toolbar.py:343, in inspector_gui.<locals>.close_btn_click(change)
#     341 def close_btn_click(change):
#     342     if change["new"]:
# --> 343         m.tool_control.cleanup()
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/geemap/toolbar.py:3983, in _cleanup_toolbar_item.<locals>.wrapper.<locals>.cleanup_and_toggle_off()
#    3981 def cleanup_and_toggle_off():
#    3982     cleanup()
# -> 3983     item.toggle_off()
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/geemap/toolbar.py:78, in ToolbarItem.toggle_off(self)
#      76 def toggle_off(self):
#      77     if self.active:
# ---> 78         self.active = False
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/traitlets/traitlets.py:706, in TraitType.set(self, obj, value)
#     702     silent = False
#     703 if silent is not True:
#     704     # we explicitly compare silent to True just in case the equality
#     705     # comparison above returns something other than True/False
# --> 706     obj._notify_trait(self.name, old_value, new_value)
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/traitlets/traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/ipywidgets/widgets/widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/traitlets/traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/traitlets/traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/geemap/toolbar.py:83, in ToolbarItem._observe_value(self, change)
#      80 @traitlets.observe("active")
#      81 def _observe_value(self, change: Dict[str, Any]) -> None:
#      82     if (value := change.get("new")) is not None:
# ---> 83         self.callback_wrapper(self.callback, value, self)
#      84     if self.active and self.reset:
#      85         self.active = False
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/geemap/toolbar.py:133, in Toolbar.__init__.<locals>.<lambda>(callback, value, tool)
#     131 self.extra_tools = extra_tools
#     132 for widget in self.main_tools + self.extra_tools:
# --> 133     widget.callback_wrapper = lambda callback, value, tool: callback(
#     134         self.host_map, value, tool
#     135     )
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/geemap/toolbar.py:3990, in _cleanup_toolbar_item.<locals>.wrapper(map, selected, item)
#    3988             item.control.cleanup = cleanup_and_toggle_off
#    3989 elif item.control and hasattr(item.control, "cleanup"):
# -> 3990     item.control.cleanup()
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/geemap/toolbar.py:3982, in _cleanup_toolbar_item.<locals>.wrapper.<locals>.cleanup_and_toggle_off()
#    3981 def cleanup_and_toggle_off():
# -> 3982     cleanup()
#    3983     item.toggle_off()
#
# File ~/Library/jupyterlab-desktop/jlab_server/envs/gee/lib/python3.14/site-packages/geemap/toolbar.py:327, in inspector_gui.<locals>.cleanup()
#     324     m.tool_control = None
#     325 m.default_style = {"cursor": "default"}
# --> 327 m.marker_cluster.markers = []
#     328 m.pixel_values = []
#     329 marker_cluster_layer = m.find_layer("Inspector Markers")
#
# AttributeError: 'method' object has no attribute 'markers' and no __dict__ for setting new attributes

# %%
Map = geemap.Map()
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topright', transp…

# %%
# ------------------------------------
# User Inputs
# ------------------------------------
aoi = ee.Geometry.Polygon(
[[[5.608534480510099, 46.698303309141494],
[5.608534480510099, 45.80952394852957],
[7.476210261760099, 45.80952394852957],
[7.476210261760099, 46.698303309141494]]])
Map.addLayer(aoi,{},'AOI')
Map.centerObject(aoi, 9)

startDate = '2023-01-01'
endDate = '2024-01-01'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ------------------------------------
# Load Landsat 8 Collection 2 Level 2
# ------------------------------------
collection = (
    ee.ImageCollection('LANDSAT/LC08/C02/T1_L2')
    .filterBounds(aoi)
    .filterDate(startDate, endDate)
    .filter(ee.Filter.lt('CLOUD_COVER', 20))
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ------------------------------------
# Functions
# ------------------------------------
def apply_scaling(image):
    # Surface Reflectance scaling
    sr = image.select(['SR_B4', 'SR_B5']) \
              .multiply(0.0000275).add(-0.2)

    # Land Surface Temperature scaling (Kelvin)
    lst = image.select('ST_B10') \
               .multiply(0.00341802).add(149.0)

    return image.addBands(sr, None, True) \
                .addBands(lst.rename('LST'), None, True)

def add_ndvi(image):
    ndvi = image.normalizedDifference(['SR_B5', 'SR_B4']).rename('NDVI')
    return image.addBands(ndvi)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ------------------------------------
# Preprocess collection
# ------------------------------------
processed = (
    collection
    .map(apply_scaling)
    .map(add_ndvi)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ------------------------------------
# Compute NDVI & LST statistics
# ------------------------------------
ndvi_min = processed.select('NDVI').min()
ndvi_max = processed.select('NDVI').max()

lst_min = processed.select('LST').min()
lst_max = processed.select('LST').max()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ------------------------------------
# Use median composite
# ------------------------------------
image = processed.median()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ------------------------------------
# Compute VCI
# ------------------------------------
vci = image.expression(
    '100 * (ndvi - ndvi_min) / (ndvi_max - ndvi_min)', {
        'ndvi': image.select('NDVI'),
        'ndvi_min': ndvi_min,
        'ndvi_max': ndvi_max
    }).rename('VCI')

# ------------------------------------
# Compute TCI
# ------------------------------------
tci = image.expression(
    '100 * (lst_max - lst) / (lst_max - lst_min)', {
        'lst': image.select('LST'),
        'lst_min': lst_min,
        'lst_max': lst_max
    }).rename('TCI')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ------------------------------------
# Compute VHI
# ------------------------------------
vhi = vci.multiply(0.5).add(tci.multiply(0.5)).rename('VHI')

# ------------------------------------
# Final Image
# ------------------------------------
vhi_image = image.addBands([vci, tci, vhi]).clip(aoi)

# Compute min and max values over the AOI
vhi_stats = vhi.reduceRegion(
    reducer=ee.Reducer.minMax(),
    geometry=aoi,
    scale=30,
    maxPixels=1e9
)

# Visualization parameters
vis_params = {
    'min': vhi_stats.get('VHI_min').getInfo(),
    'max': vhi_stats.get('VHI_max').getInfo(),
    'palette': ['red', 'white', 'green']
}

#Visualize NDVI
Map.addLayer(vhi.clip(aoi), vis_params, 'Landsat | VHI')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ------------------------------------
# Export to Google Drive
# ------------------------------------
task = ee.batch.Export.image.toDrive(
    image=vhi_image.select('VHI'),
    description='Landsat8_VHI',
    folder='GEE',
    scale=30,
    region=roi,
    maxPixels=1e13
)

task.start()

print("Export started!")

# %% [markdown]
# ## Monthly VHI
# Dataset: Landsat 8 Collection 2 Level-2
# Cloud masking: QA_PIXEL (cloud, cloud shadow, cirrus, snow)
# Temporal resolution: Monthly composites
# Baseline: Same period used for NDVI/LST min–max (can easily be expanded to multi-year)
# Plot: Mean VHI over ROI vs time

# %%
import ee
import geemap

import pandas as pd
import matplotlib.pyplot as plt
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Map = geemap.Map()
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topright', transp…

# %%
# ------------------------------------
# USER INPUTS
# ------------------------------------
roi = ee.Geometry.Polygon(
[[[5.608534480510099, 46.698303309141494],
[5.608534480510099, 45.80952394852957],
[7.476210261760099, 45.80952394852957],
[7.476210261760099, 46.698303309141494]]])
Map.addLayer(aoi,{},'AOI')
Map.centerObject(aoi, 9)

start_date = '2022-01-01'
end_date = '2023-12-31'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ------------------------------------
# Cloud Mask using QA_PIXEL
# ------------------------------------
def mask_landsat_qa(image):
    qa = image.select('QA_PIXEL')

    # Bits (Landsat C2 L2)
    cloud_shadow = 1 << 4
    snow = 1 << 5
    cloud = 1 << 3
    cirrus = 1 << 2

    mask = (
        qa.bitwiseAnd(cloud_shadow).eq(0)
        .And(qa.bitwiseAnd(snow).eq(0))
        .And(qa.bitwiseAnd(cloud).eq(0))
        .And(qa.bitwiseAnd(cirrus).eq(0))
    )

    return image.updateMask(mask)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ------------------------------------
# Scaling Functions
# ------------------------------------
def apply_scaling(image):
    # Surface Reflectance
    sr = image.select(['SR_B4', 'SR_B5']) \
              .multiply(0.0000275).add(-0.2)

    # Land Surface Temperature (Kelvin)
    lst = image.select('ST_B10') \
               .multiply(0.00341802).add(149.0) \
               .rename('LST')

    return image.addBands(sr, None, True).addBands(lst, None, True)

def add_ndvi(image):
    ndvi = image.normalizedDifference(['SR_B5', 'SR_B4']).rename('NDVI')
    return image.addBands(ndvi)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ------------------------------------
# Load & Preprocess Collection
# ------------------------------------
collection = (
    ee.ImageCollection('LANDSAT/LC08/C02/T1_L2')
    .filterBounds(roi)
    .filterDate(start_date, end_date)
    .map(mask_landsat_qa)
    .map(apply_scaling)
    .map(add_ndvi)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ------------------------------------
# NDVI & LST Min/Max (Baseline)
# ------------------------------------
ndvi_min = collection.select('NDVI').min()
ndvi_max = collection.select('NDVI').max()
lst_min = collection.select('LST').min()
lst_max = collection.select('LST').max()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ------------------------------------
# Monthly VHI Function
# ------------------------------------
def monthly_vhi(year, month):
    start = ee.Date.fromYMD(year, month, 1)
    end = start.advance(1, 'month')

    monthly_col = collection.filterDate(start, end)

    # If collection is empty, return empty image
    img = ee.Image(
        ee.Algorithms.If(
            monthly_col.size().gt(0),
            monthly_col.median(),
            ee.Image()
        )
    )

    # Check NDVI band exists
    has_ndvi = img.bandNames().contains('NDVI')

    vhi = ee.Image(
        ee.Algorithms.If(
            has_ndvi,

            # --- Compute VHI ---
            img.expression(
                '0.5 * (100 * (ndvi - ndvi_min) / (ndvi_max - ndvi_min)) + \
                 0.5 * (100 * (lst_max - lst) / (lst_max - lst_min))',
                {
                    'ndvi': img.select('NDVI'),
                    'ndvi_min': ndvi_min,
                    'ndvi_max': ndvi_max,
                    'lst': img.select('LST'),
                    'lst_min': lst_min,
                    'lst_max': lst_max
                }
            ).rename('VHI'),

            # --- Empty image fallback ---
            ee.Image().rename('VHI')
        )
    )

    return (
        vhi
        .set('year', year)
        .set('month', month)
        .set('system:time_start', start.millis())
    )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ------------------------------------
# Create Monthly ImageCollection
# ------------------------------------
years = ee.List.sequence(2021, 2022)
months = ee.List.sequence(1, 12)

monthly_images = ee.ImageCollection.fromImages(
    years.map(
        lambda y: months.map(
            lambda m: monthly_vhi(ee.Number(y), ee.Number(m))
        )
    ).flatten()
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ------------------------------------
# Extract Mean VHI Time Series
# ------------------------------------
def region_mean(image):
    mean = image.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=roi,
        scale=30,
        maxPixels=1e13
    )
    return ee.Feature(None, {
        'date': ee.Date(image.get('system:time_start')).format('YYYY-MM'),
        'VHI': mean.get('VHI')
    })

vhi_ts = monthly_images.map(region_mean).getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# ------------------------------------
# Convert to Pandas DataFrame
# ------------------------------------
dates = []
values = []

for f in vhi_ts['features']:
    if f['properties']['VHI'] is not None:
        dates.append(f['properties']['date'])
        values.append(f['properties']['VHI'])

df = pd.DataFrame({
    'Date': pd.to_datetime(dates),
    'VHI': values
}).sort_values('Date')

# ------------------------------------
# Plot Time Series
# ------------------------------------
plt.figure(figsize=(10, 5))
plt.plot(df['Date'], df['VHI'], marker='o')
plt.axhline(40, linestyle='--', linewidth=1)
plt.axhline(60, linestyle='--', linewidth=1)
plt.ylabel('VHI')
plt.xlabel('Date')
plt.title('Monthly Vegetation Health Index (VHI)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 8
#       5 values = []
#       7 for f in vhi_ts['features']:
# ----> 8     if f['properties']['VHI'] is not None:
#       9         dates.append(f['properties']['date'])
#      10         values.append(f['properties']['VHI'])
#
# KeyError: 'VHI'
